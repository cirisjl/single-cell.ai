# %%
import os
import subprocess
import sys
sys.path.append('..')
from tools.qc.scanpy_qc import scanpy_qc
from tools.qc.dropkick_qc import dropkick_qc
from tools.formating.formating import *
import anndata as ad
import pandas as pd
# from tools.run_qc import run_qc
# Out:
# scanpy==1.9.5 anndata==0.9.2 umap==0.5.4 numpy==1.22.4 scipy==1.9.1 pandas==1.3.5 scikit-learn==1.3.1 statsmodels==0.14.0 igraph==0.10.8 pynndescent==0.5.10
# scanpy==1.9.5 anndata==0.9.2 umap==0.5.4 numpy==1.22.4 scipy==1.9.1 pandas==1.3.5 scikit-learn==1.3.1 statsmodels==0.14.0 igraph==0.10.8 pynndescent==0.5.10

# %%
adata = ad.read_csv('/ps/ai-ready/data/Clustering/Tabula_Muris/FACS/Kidney-counts.csv')
adata
# Out:
# AnnData object with n_obs × n_vars = 23433 × 865

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_ann = pd.read_csv('/ps/ai-ready/data/Clustering/Tabula_Muris/annotations_facs.csv', index_col=None)
df_ann = df_ann.set_index('cell', drop=False)
df_ann
# Out:
#                          Neurog3>0_raw Neurog3>0_scaled  \
# cell
# A1.B000610.3_56_F.1.1              NaN              NaN
# A1.B002764.3_38_F.1.1              NaN              NaN
# A1.B002771.3_39_F.1.1              NaN              NaN
# A1.D041914.3_8_M.1.1               NaN              NaN
# A1.D042253.3_9_M.1.1               NaN              NaN
# ...                                ...              ...
# P22.B002431.3_39_F.1.1             NaN              NaN
# P22.MAA000906.3_11_M.1.1           NaN              NaN
# P22.MAA000908.3_10_M.1.1           NaN              NaN
# P5.MAA000595.3_9_M.1.1             NaN              NaN
# P8.MAA000595.3_9_M.1.1             NaN              NaN
#
#                                               cell      cell_ontology_class  \
# cell
# A1.B000610.3_56_F.1.1        A1.B000610.3_56_F.1.1             bladder cell
# A1.B002764.3_38_F.1.1        A1.B002764.3_38_F.1.1  bladder urothelial cell
# ...

# %%
adata.var = adata.var.join(df_ann)
adata.var
# Out:
#                         Neurog3>0_raw Neurog3>0_scaled  \
# A14.MAA000545.3_8_M.1.1           NaN              NaN
# E1.MAA000545.3_8_M.1.1            NaN              NaN
# M4.MAA000545.3_8_M.1.1            NaN              NaN
# O21.MAA000545.3_8_M.1.1           NaN              NaN
# P4.MAA000545.3_8_M.1.1            NaN              NaN
# ...                               ...              ...
# P4.B002775.3_39_F.1.1             NaN              NaN
# N7.B002775.3_39_F.1.1             NaN              NaN
# P6.B002775.3_39_F.1.1             NaN              NaN
# N8.B002775.3_39_F.1.1             NaN              NaN
# P7.B002775.3_39_F.1.1             NaN              NaN
#
#                                             cell  \
# A14.MAA000545.3_8_M.1.1  A14.MAA000545.3_8_M.1.1
# E1.MAA000545.3_8_M.1.1    E1.MAA000545.3_8_M.1.1
# M4.MAA000545.3_8_M.1.1    M4.MAA000545.3_8_M.1.1
# O21.MAA000545.3_8_M.1.1  O21.MAA000545.3_8_M.1.1
# P4.MAA000545.3_8_M.1.1    P4.MAA000545.3_8_M.1.1
# ...

# %%
adata.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
adata_merge = pd.merge(adata.var, df_ann, how='left', left_index=True, right_on='cell', sort=False)
adata_merge

# %%
adata1 = ad.read_h5ad('/ps/ai-ready/data/Clustering/Tabula_Sapiens/TS_germ line.h5ad')
adata1

# %%
adata1.var

# %%
adata1.obs
